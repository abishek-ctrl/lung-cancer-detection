# %% [markdown]
# <a href="https://colab.research.google.com/github/abishek-ctrl/Cancer_Dataset/blob/main/loading_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://zenodo.org/record/3723295/files/seg-lungs-LUNA16.zip
# Out:
# --2021-09-29 13:58:39--  https://zenodo.org/record/3723295/files/seg-lungs-LUNA16.zip
# Resolving zenodo.org (zenodo.org)... 137.138.76.77
# Connecting to zenodo.org (zenodo.org)|137.138.76.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 303871549 (290M) [application/octet-stream]
# Saving to: ‘seg-lungs-LUNA16.zip’
#
# seg-lungs-LUNA16.zi 100%[===================>] 289.79M  10.4MB/s    in 45s
#
# 2021-09-29 13:59:25 (6.41 MB/s) - ‘seg-lungs-LUNA16.zip’ saved [303871549/303871549]

# %%
# !unzip seg-lungs-LUNA16.zip
# Out:
# Archive:  seg-lungs-LUNA16.zip
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840553388986847034053.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840553388986847034053.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926682752765845212286.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926682752765845212286.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100620385482151095585000946543.mhd
# ...

# %%
file_folder="seg-lungs-LUNA16.zip"
# !unzip "$file_folder"
# Out:
# Archive:  seg-lungs-LUNA16.zip
# replace seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.mhd
# replace seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.zraw? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.zraw? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840553388986847034053.mhd
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840553388986847034053.zraw
#   inflating: seg-lungs-LUNA16/1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793540579077826395208.mhd
# ...

# %%
data =!wget https://zenodo.org/record/3723295/files/subset0.zip
# Out:
# subset0.zip         100%[===================>]   6.34G  3.71MB/s    in 24m 47s
#
# 2021-09-29 14:38:48 (4.37 MB/s) - ‘subset0.zip’ saved [6811924508/6811924508]

# %%
# !jar xvf subset0.zip
# Out:
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.mhd
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.105756658031515062000744821260.raw
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.mhd
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.108197895896446896160048741492.raw
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.mhd
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.109002525524522225658609808059.raw
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987.mhd
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.111172165674661221381920536987.raw
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.122763913896761494371822656720.mhd
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.122763913896761494371822656720.raw
#  inflated: subset0/1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565.mhd
# ...

# %%
#Edit:29-09-2021 :(
